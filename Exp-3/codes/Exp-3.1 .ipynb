# %% [markdown]
# #  Experiment 3
#
# # Title: Data Wrangling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 3.1 Dataset:
# - Dataset is a collection of data objects which are observations, entries, samples, cases, etc. It could be a structured table, image data, video data or anything else.

# %%
movies = pd.read_csv("C:/Users/acer/Desktop/movie.csv")

# %% [markdown]
# ### 3.2 Data Preprocessing:
# - Data preprocessing is an important step in which the data gets transformed or brought in usable format such that the machine can understand or interpret it.
#
# ### 3.3 Data feature:
# - A feature is a measurable property of the dataset which are also known as attributes, fields or dimensions.

# %%
movies.head(100)
# Out:
#     color      director_name  num_critic_for_reviews  duration  \
# 0   Color      James Cameron                   723.0     178.0
# 1   Color     Gore Verbinski                   302.0     169.0
# 2   Color         Sam Mendes                   602.0     148.0
# 3   Color  Christopher Nolan                   813.0     164.0
# 4     NaN        Doug Walker                     NaN       NaN
# ..    ...                ...                     ...       ...
# 95  Color         James Gunn                   653.0     121.0
# 96  Color  Christopher Nolan                   712.0     169.0
# 97  Color  Christopher Nolan                   642.0     148.0
# 98  Color       Hideaki Anno                     1.0     120.0
# 99  Color      Peter Jackson                   645.0     182.0
#
#     director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                       0.0                   855.0   Joel David Moore
# 1                     563.0                  1000.0      Orlando Bloom
# 2                       0.0                   161.0       Rory Kinnear
# 3                   22000.0                 23000.0     Christian Bale
# 4                     131.0                     NaN         Rob Walker
# ..                      ...                     ...                ...
# 95                    571.0                  3000.0         Vin Diesel
# 96                  22000.0                  6000.0      Anne Hathaway
# 97                  22000.0                 23000.0          Tom Hardy
# 98                     28.0                    12.0  Shin'ya Tsukamoto
# 99                      0.0                   773.0         Adam Brown
#
#     actor_1_facebook_likes        gross                                genres  \
# 0                   1000.0  760505847.0       Action|Adventure|Fantasy|Sci-Fi
# 1                  40000.0  309404152.0              Action|Adventure|Fantasy
# 2                  11000.0  200074175.0             Action|Adventure|Thriller
# 3                  27000.0  448130642.0                       Action|Thriller
# 4                    131.0          NaN                           Documentary
# ..                     ...          ...                                   ...
# 95                 14000.0  333130696.0               Action|Adventure|Sci-Fi
# 96                 11000.0  187991439.0                Adventure|Drama|Sci-Fi
# 97                 29000.0  292568851.0      Action|Adventure|Sci-Fi|Thriller
# 98                   544.0          NaN  Action|Adventure|Drama|Horror|Sci-Fi
# 99                  5000.0  303001229.0                     Adventure|Fantasy
#
#     ... num_user_for_reviews  language  country  content_rating       budget  \
# 0   ...               3054.0   English      USA           PG-13  237000000.0
# 1   ...               1238.0   English      USA           PG-13  300000000.0
# 2   ...                994.0   English       UK           PG-13  245000000.0
# 3   ...               2701.0   English      USA           PG-13  250000000.0
# 4   ...                  NaN       NaN      NaN             NaN          NaN
# ..  ...                  ...       ...      ...             ...          ...
# 95  ...               1097.0   English      USA           PG-13  170000000.0
# 96  ...               2725.0   English      USA           PG-13  165000000.0
# 97  ...               2803.0   English      USA           PG-13  160000000.0
# 98  ...                 13.0  Japanese    Japan             NaN          NaN
# 99  ...               1367.0   English      USA           PG-13  180000000.0
#
#     title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0       2009.0                  936.0        7.9          1.78
# 1       2007.0                 5000.0        7.1          2.35
# 2       2015.0                  393.0        6.8          2.35
# 3       2012.0                23000.0        8.5          2.35
# 4          NaN                   12.0        7.1           NaN
# ..         ...                    ...        ...           ...
# 95      2014.0                14000.0        8.1          2.35
# 96      2014.0                11000.0        8.6          2.35
# 97      2010.0                27000.0        8.8          2.35
# 98      2016.0                  106.0        8.2          2.35
# 99      2012.0                  972.0        7.9          2.35
#
#    movie_facebook_likes
# 0                 33000
# 1                     0
# 2                 85000
# 3                164000
# 4                     0
# ..                  ...
# 95                96000
# 96               349000
# 97               175000
# 98                    0
# 99               166000
#
# [100 rows x 28 columns]

# %%
movies['title_year'].min()
# Out:
# 1916.0

# %%
a=movies[['director_name','movie_title','budget','director_facebook_likes', 'imdb_score']]

# %%
a
# Out:
#           director_name                                 movie_title  \
# 0         James Cameron                                      Avatar
# 1        Gore Verbinski    Pirates of the Caribbean: At World's End
# 2            Sam Mendes                                     Spectre
# 3     Christopher Nolan                       The Dark Knight Rises
# 4           Doug Walker  Star Wars: Episode VII - The Force Awakens
# ...                 ...                                         ...
# 4911        Scott Smith                     Signed Sealed Delivered
# 4912                NaN                               The Following
# 4913   Benjamin Roberds                        A Plague So Pleasant
# 4914        Daniel Hsia                            Shanghai Calling
# 4915           Jon Gunn                           My Date with Drew
#
#            budget  director_facebook_likes  imdb_score
# 0     237000000.0                      0.0         7.9
# 1     300000000.0                    563.0         7.1
# 2     245000000.0                      0.0         6.8
# 3     250000000.0                  22000.0         8.5
# 4             NaN                    131.0         7.1
# ...           ...                      ...         ...
# 4911          NaN                      2.0         7.7
# 4912          NaN                      NaN         7.5
# 4913       1400.0                      0.0         6.3
# 4914          NaN                      0.0         6.3
# 4915       1100.0                     16.0         6.6
#
# [4916 rows x 5 columns]

# %% [markdown]
# ### 3.4 Missing Values:
# - Data is taken from multiple sources which can be unreliable in some cases.
# - There may be human or machine errors during the data collection process. And so we often deal with the missing data or some other format data in our datasets.

# %%
a['budget'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 4911     True
# 4912     True
# 4913    False
# 4914     True
# 4915    False
# Name: budget, Length: 4916, dtype: bool

# %% [markdown]
# ### 3.5 Data Normalization:
# - Normalization refers to rescaling real valued numeric attributes into the range 0 and 1.

# %%
new = a['budget'].fillna(25)  # replaces Nan values with user given values

# %%
new
# Out:
# 0       237000000.0
# 1       300000000.0
# 2       245000000.0
# 3       250000000.0
# 4              25.0
#            ...
# 4911           25.0
# 4912           25.0
# 4913         1400.0
# 4914           25.0
# 4915         1100.0
# Name: budget, Length: 4916, dtype: float64

# %%
a['imdb_score'].isnull().sum()
# Out:
# 0

# %%
np.nan == None
# Out:
# False

# %%
a['imdb_score'] + 1
# Out:
# 0       8.9
# 1       8.1
# 2       7.8
# 3       9.5
# 4       8.1
#        ...
# 4911    8.7
# 4912    8.5
# 4913    7.3
# 4914    7.3
# 4915    7.6
# Name: imdb_score, Length: 4916, dtype: float64

# %%
del a['director_facebook_likes']

# %%
a
# Out:
#           director_name                                 movie_title  \
# 0         James Cameron                                      Avatar
# 1        Gore Verbinski    Pirates of the Caribbean: At World's End
# 2            Sam Mendes                                     Spectre
# 3     Christopher Nolan                       The Dark Knight Rises
# 4           Doug Walker  Star Wars: Episode VII - The Force Awakens
# ...                 ...                                         ...
# 4911        Scott Smith                     Signed Sealed Delivered
# 4912                NaN                               The Following
# 4913   Benjamin Roberds                        A Plague So Pleasant
# 4914        Daniel Hsia                            Shanghai Calling
# 4915           Jon Gunn                           My Date with Drew
#
#            budget  imdb_score
# 0     237000000.0         7.9
# 1     300000000.0         7.1
# 2     245000000.0         6.8
# 3     250000000.0         8.5
# 4             NaN         7.1
# ...           ...         ...
# 4911          NaN         7.7
# 4912          NaN         7.5
# 4913       1400.0         6.3
# 4914          NaN         6.3
# 4915       1100.0         6.6
#
# [4916 rows x 4 columns]

# %%
a.set_index('movie_title')
# Out:
#                                                 director_name       budget  \
# movie_title
# Avatar                                          James Cameron  237000000.0
# Pirates of the Caribbean: At World's End       Gore Verbinski  300000000.0
# Spectre                                            Sam Mendes  245000000.0
# The Dark Knight Rises                       Christopher Nolan  250000000.0
# Star Wars: Episode VII - The Force Awakens        Doug Walker          NaN
# ...                                                       ...          ...
# Signed Sealed Delivered                           Scott Smith          NaN
# The Following                                             NaN          NaN
# A Plague So Pleasant                         Benjamin Roberds       1400.0
# Shanghai Calling                                  Daniel Hsia          NaN
# My Date with Drew                                    Jon Gunn       1100.0
#
#                                             imdb_score
# movie_title
# Avatar                                             7.9
# Pirates of the Caribbean: At World's End           7.1
# Spectre                                            6.8
# The Dark Knight Rises                              8.5
# Star Wars: Episode VII - The Force Awakens         7.1
# ...                                                ...
# Signed Sealed Delivered                            7.7
# The Following                                      7.5
# A Plague So Pleasant                               6.3
# Shanghai Calling                                   6.3
# My Date with Drew                                  6.6
#
# [4916 rows x 3 columns]

# %%
a.reset_index()
# Out:
#       index      director_name                                 movie_title  \
# 0         0      James Cameron                                      Avatar
# 1         1     Gore Verbinski    Pirates of the Caribbean: At World's End
# 2         2         Sam Mendes                                     Spectre
# 3         3  Christopher Nolan                       The Dark Knight Rises
# 4         4        Doug Walker  Star Wars: Episode VII - The Force Awakens
# ...     ...                ...                                         ...
# 4911   4911        Scott Smith                     Signed Sealed Delivered
# 4912   4912                NaN                               The Following
# 4913   4913   Benjamin Roberds                        A Plague So Pleasant
# 4914   4914        Daniel Hsia                            Shanghai Calling
# 4915   4915           Jon Gunn                           My Date with Drew
#
#            budget  imdb_score
# 0     237000000.0         7.9
# 1     300000000.0         7.1
# 2     245000000.0         6.8
# 3     250000000.0         8.5
# 4             NaN         7.1
# ...           ...         ...
# 4911          NaN         7.7
# 4912          NaN         7.5
# 4913       1400.0         6.3
# 4914          NaN         6.3
# 4915       1100.0         6.6
#
# [4916 rows x 5 columns]

# %%
var = a.rename(columns={'movie_title':'name_of_movie'}).head()

# %%
var.filter(like='name').head()
# Out:
#        director_name                               name_of_movie
# 0      James Cameron                                      Avatar
# 1     Gore Verbinski    Pirates of the Caribbean: At World's End
# 2         Sam Mendes                                     Spectre
# 3  Christopher Nolan                       The Dark Knight Rises
# 4        Doug Walker  Star Wars: Episode VII - The Force Awakens

# %%
a.tail()
# Out:
#          director_name              movie_title  budget  \
# 4911       Scott Smith  Signed Sealed Delivered     NaN
# 4912               NaN            The Following     NaN
# 4913  Benjamin Roberds     A Plague So Pleasant  1400.0
# 4914       Daniel Hsia         Shanghai Calling     NaN
# 4915          Jon Gunn        My Date with Drew  1100.0
#
#       director_facebook_likes  imdb_score
# 4911                      2.0           0
# 4912                      NaN           0
# 4913                      0.0           0
# 4914                      0.0           0
# 4915                     16.0           0

# %%
s=a['imdb_score']>5

# %%
s.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: imdb_score, dtype: bool

# %%
a.loc[s]
# Out:
#           director_name                                 movie_title  \
# 0         James Cameron                                      Avatar
# 1        Gore Verbinski    Pirates of the Caribbean: At World's End
# 2            Sam Mendes                                     Spectre
# 3     Christopher Nolan                       The Dark Knight Rises
# 4           Doug Walker  Star Wars: Episode VII - The Force Awakens
# ...                 ...                                         ...
# 4911        Scott Smith                     Signed Sealed Delivered
# 4912                NaN                               The Following
# 4913   Benjamin Roberds                        A Plague So Pleasant
# 4914        Daniel Hsia                            Shanghai Calling
# 4915           Jon Gunn                           My Date with Drew
#
#            budget  director_facebook_likes  imdb_score
# 0     237000000.0                      0.0         7.9
# 1     300000000.0                    563.0         7.1
# 2     245000000.0                      0.0         6.8
# 3     250000000.0                  22000.0         8.5
# 4             NaN                    131.0         7.1
# ...           ...                      ...         ...
# 4911          NaN                      2.0         7.7
# 4912          NaN                      NaN         7.5
# 4913       1400.0                      0.0         6.3
# 4914          NaN                      0.0         6.3
# 4915       1100.0                     16.0         6.6
#
# [4399 rows x 5 columns]

# %%
a.head()
# Out:
#        director_name                                 movie_title       budget  \
# 0      James Cameron                                      Avatar  237000000.0
# 1     Gore Verbinski    Pirates of the Caribbean: At World's End  300000000.0
# 2         Sam Mendes                                     Spectre  245000000.0
# 3  Christopher Nolan                       The Dark Knight Rises  250000000.0
# 4        Doug Walker  Star Wars: Episode VII - The Force Awakens          NaN
#
#    director_facebook_likes  imdb_score
# 0                      0.0           0
# 1                    563.0           0
# 2                      0.0           0
# 3                  22000.0           0
# 4                    131.0           0

# %%
a
# Out:
#           director_name                                 movie_title  \
# 0         James Cameron                                      Avatar
# 1        Gore Verbinski    Pirates of the Caribbean: At World's End
# 2            Sam Mendes                                     Spectre
# 3     Christopher Nolan                       The Dark Knight Rises
# 4           Doug Walker  Star Wars: Episode VII - The Force Awakens
# ...                 ...                                         ...
# 4911        Scott Smith                     Signed Sealed Delivered
# 4912                NaN                               The Following
# 4913   Benjamin Roberds                        A Plague So Pleasant
# 4914        Daniel Hsia                            Shanghai Calling
# 4915           Jon Gunn                           My Date with Drew
#
#            budget  director_facebook_likes  imdb_score
# 0     237000000.0                      0.0           7
# 1     300000000.0                    563.0           0
# 2     245000000.0                      0.0           0
# 3     250000000.0                  22000.0           0
# 4             NaN                    131.0           0
# ...           ...                      ...         ...
# 4911          NaN                      2.0           0
# 4912          NaN                      NaN           0
# 4913       1400.0                      0.0           0
# 4914          NaN                      0.0           0
# 4915       1100.0                     16.0           0
#
# [4916 rows x 5 columns]

# %%
critria
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 4911     True
# 4912     True
# 4913    False
# 4914    False
# 4915    False
# Name: imdb_score, Length: 4916, dtype: bool

# %%
movies.loc[critria]
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# 7     Color       Nathan Greno                   324.0     100.0
# ...     ...                ...                     ...       ...
# 4900  Color       Jafar Panahi                    64.0      90.0
# 4902  Color   Kiyoshi Kurosawa                    78.0     111.0
# 4909  Color    Anthony Vallone                     NaN      84.0
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# 1                       563.0                  1000.0      Orlando Bloom
# 3                     22000.0                 23000.0     Christian Bale
# 4                       131.0                     NaN         Rob Walker
# 7                        15.0                   284.0       Donna Murphy
# ...                       ...                     ...                ...
# 4900                    397.0                     0.0  Nargess Mamizadeh
# 4902                     62.0                     6.0      Anna Nakagawa
# 4909                      2.0                     2.0     John Considine
# 4911                      2.0                   318.0      Daphne Zuniga
# 4912                      NaN                   319.0      Valorie Curry
#
#       actor_1_facebook_likes        gross  \
# 0                     1000.0  760505847.0
# 1                    40000.0  309404152.0
# 3                    27000.0  448130642.0
# 4                      131.0          NaN
# 7                      799.0  200807262.0
# ...                      ...          ...
# 4900                     5.0     673780.0
# 4902                    89.0      94596.0
# 4909                    45.0          NaN
# 4911                   637.0          NaN
# 4912                   841.0          NaN
#
#                                                  genres  ...  \
# 0                       Action|Adventure|Fantasy|Sci-Fi  ...
# 1                              Action|Adventure|Fantasy  ...
# 3                                       Action|Thriller  ...
# 4                                           Documentary  ...
# 7     Adventure|Animation|Comedy|Family|Fantasy|Musi...  ...
# ...                                                 ...  ...
# 4900                                              Drama  ...
# 4902                      Crime|Horror|Mystery|Thriller  ...
# 4909                                        Crime|Drama  ...
# 4911                                       Comedy|Drama  ...
# 4912                       Crime|Drama|Mystery|Thriller  ...
#
#      num_user_for_reviews  language  country  content_rating       budget  \
# 0                  3054.0   English      USA           PG-13  237000000.0
# 1                  1238.0   English      USA           PG-13  300000000.0
# 3                  2701.0   English      USA           PG-13  250000000.0
# 4                     NaN       NaN      NaN             NaN          NaN
# 7                   387.0   English      USA              PG  260000000.0
# ...                   ...       ...      ...             ...          ...
# 4900                 26.0   Persian     Iran       Not Rated      10000.0
# 4902                 50.0  Japanese    Japan             NaN    1000000.0
# 4909                  1.0   English      USA           PG-13       3250.0
# 4911                  6.0   English   Canada             NaN          NaN
# 4912                359.0   English      USA           TV-14          NaN
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0         2009.0                  936.0        7.9          1.78
# 1         2007.0                 5000.0        7.1          2.35
# 3         2012.0                23000.0        8.5          2.35
# 4            NaN                   12.0        7.1           NaN
# 7         2010.0                  553.0        7.8          1.85
# ...          ...                    ...        ...           ...
# 4900      2000.0                    0.0        7.5          1.85
# 4902      1997.0                   13.0        7.4          1.85
# 4909      2005.0                   44.0        7.8           NaN
# 4911      2013.0                  470.0        7.7           NaN
# 4912         NaN                  593.0        7.5         16.00
#
#      movie_facebook_likes
# 0                   33000
# 1                       0
# 3                  164000
# 4                       0
# 7                   29000
# ...                   ...
# 4900                  697
# 4902                  817
# 4909                    4
# 4911                   84
# 4912                32000
#
# [1546 rows x 28 columns]

# %%
movies.loc[1:6:2]   # loc is for selecting particular or multiples rows
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 1  Color     Gore Verbinski                   302.0     169.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 5  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes     actor_2_name  \
# 1                    563.0                  1000.0    Orlando Bloom
# 3                  22000.0                 23000.0   Christian Bale
# 5                    475.0                   530.0  Samantha Morton
#
#    actor_1_facebook_likes        gross                    genres  ...  \
# 1                 40000.0  309404152.0  Action|Adventure|Fantasy  ...
# 3                 27000.0  448130642.0           Action|Thriller  ...
# 5                   640.0   73058679.0   Action|Adventure|Sci-Fi  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 1               1238.0  English      USA           PG-13  300000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 5                738.0  English      USA           PG-13  263700000.0
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 1      2007.0                 5000.0        7.1          2.35
# 3      2012.0                23000.0        8.5          2.35
# 5      2012.0                  632.0        6.6          2.35
#
#   movie_facebook_likes
# 1                    0
# 3               164000
# 5                24000
#
# [3 rows x 28 columns]

# %%
movies.loc[0:3].head()[['director_name', 'gross']]     # for selecting multiple row and cols simul.
# Out:
#        director_name        gross
# 0      James Cameron  760505847.0
# 1     Gore Verbinski  309404152.0
# 2         Sam Mendes  200074175.0
# 3  Christopher Nolan  448130642.0

# %%
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 3.6 Binning:
#
# - Binning is used for data smoothing and also to remove noisy data, this is done by converting continuous variables into categorical variables. In this method the data is initially sorted and then the sorted values are distributed into different bins. There are mainly two
# types in unsupervised binning:
# a)Equal Frequency binning
# b)Equal Width binning
#
# - a)Equal Frequency binning :
# This type of binning divides the data into bins such that every
# bin will be of same height i.e it will distribute the values of the data equally into formed
# categories.Using the below formula we can calculate the frequency,
#
# Freq=n/x
#
# where n = number of values in data
# x = number of categories
# Freq = frequency of the category
#
# - b)Equal Width binning :
# This type of binning divides the data into bins such that every bin will be of same width i.e it divides the continuous variable into several categories of the same range.Using the below formula we can calculate the width of the bin,
#
# W=(max-min) / x
#
# where max = maximum value in the list
# min = minimum value in the list
# x = number of categories
# W = width of category

# %%
plt.hist(movies['title_year'], bins=20, ec='black')
plt.show()

# %%
movies['title_year'].min()
# Out:
# 1916.0

# %%
movies['title_year'].max()
# Out:
# 2016.0

# %%
movies['freq_bin'] = pd.qcut(movies['title_year'], q=10)

# %% [markdown]
# ### 3.7 Turning Categorical variables into quantitative variables :
# - As the machine learning models cannot work on the categorical variables they changed into quantitative form. Using the “get_dummies()” function we can perform the task of converting the categorical variables into boolean values.

# %%
data = {'name': ['Sheldon', 'Penny', 'Amy', 'Penny', 'Raj', 'Howard'],
                'episodes': [42, 24, 31, 29, 37, 40],
                'gender': ['male', 'female', 'female', 'female', 'male', 'male']}

df = pd.DataFrame(data, columns = ['name','episodes', 'gender'])
print(df)
# Out:
#       name  episodes  gender
# 0  Sheldon        42    male
# 1    Penny        24  female
# 2      Amy        31  female
# 3    Penny        29  female
# 4      Raj        37    male
# 5   Howard        40    male

# %%
df_gender = pd.get_dummies(df['gender'])

# %%
df_gender
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1
# 5       0     1

# %%
df_new = pd.concat([df, df_gender], axis=1)
df_new
# Out:
#       name  episodes  gender  female  male
# 0  Sheldon        42    male       0     1
# 1    Penny        24  female       1     0
# 2      Amy        31  female       1     0
# 3    Penny        29  female       1     0
# 4      Raj        37    male       0     1
# 5   Howard        40    male       0     1

# %% [markdown]
# ### Names: Akshay Shete, Prachi Sathe
# ### Academic Year: 2020-21
# ### References:
# 1. https://medium.com/@urvashilluniya/why-data-normalization-is-necessary-for-machine-learning-models-681b65a05029#:~:text=Normalization%20is%20a%20technique%20often,dataset%20does%20not%20require%20normalization
# 2. https://towardsdatascience.com/data-normalization-in-machine-learning-395fdec69d02?gi=299efd7e5564
# 3. https://www.geeksforgeeks.org/binning-in-data-mining/
